# %%
import gloesspy3 as gf

import pandas as pd

# %%
from importlib import reload

# %%
reload(gf)
# Out:
# <module 'gloesspy3' from '/Users/vs522/Dropbox/Python/gloess/oo_gloess/gloesspy3.py'>

# %%
source_id = 1820309639468685824

# %%
fit_results, period, df, gloess = gf.gaia_gloess_fit_and_plot(source_id)
# Out:
# Fitting Gaia DR3 1820309639468685824
# INFO: Query finished. [astroquery.utils.tap.core]
# saved lightcurve plot to GaiaDR31820309639468685824_gloess_lc.pdf
# GaiaDR31820309639468685824_gloess_fit.csv
# Saved gloess fit to GaiaDR31820309639468685824_gloess_fit.csv

# %%
vc = pd.read_csv('/Users/vs522/OneDrive - University of Bath/Gaia_Cepheids/DR3/dr3_varicepheid-result.csv')

# %%
vc
# Out:
#               solution_id            source_id        pf  pf_error      p1_o  \
# 0      375316653866487564  4658032774371311104  6.531933  0.000265       NaN
# 1      375316653866487564  4658035626229427456       NaN       NaN  1.178930
# 2      375316653866487564  4658036274856153856       NaN       NaN  2.138628
# 3      375316653866487564  4658036828819820800       NaN       NaN  2.659445
# 4      375316653866487564  4658039710832195200  2.911573  0.000092       NaN
# ...                   ...                  ...       ...       ...       ...
# 15016  375316653866487564  4070549035679633152  1.007871  0.000007       NaN
# 15017  375316653866487564  5983575366787818112  2.175574  0.000042       NaN
# 15018  375316653866487564  3329807983320140160       NaN       NaN  3.075110
# 15019  375316653866487564  3329849043206545920  8.618491  0.001586       NaN
# 15020  375316653866487564  3329873163744496000       NaN       NaN  1.523004
#
# ...

# %%
vc[vc.mode_best_classification=='FIRST_OVERTONE']
# Out:
#               solution_id            source_id  pf  pf_error      p1_o  \
# 1      375316653866487564  4658035626229427456 NaN       NaN  1.178930
# 2      375316653866487564  4658036274856153856 NaN       NaN  2.138628
# 3      375316653866487564  4658036828819820800 NaN       NaN  2.659445
# 6      375316653866487564  4658041222673354112 NaN       NaN  0.722922
# 9      375316653866487564  4658044246159140608 NaN       NaN  2.417727
# ...                   ...                  ...  ..       ...       ...
# 15004  375316653866487564  4092672412214499328 NaN       NaN  1.405092
# 15005  375316653866487564  5961273530136727424 NaN       NaN  2.192284
# 15012  375316653866487564  2018879240446996608 NaN       NaN  0.710993
# 15018  375316653866487564  3329807983320140160 NaN       NaN  3.075110
# 15020  375316653866487564  3329873163744496000 NaN       NaN  1.523004
#
#        p1_o_error      epoch_g  epoch_g_error     epoch_bp  epoch_bp_error  \
# ...

# %%
o1_source_id = 4658035626229427456

# %%
fit_results, period, df, gloess = gf.gaia_gloess_fit_and_plot(o1_source_id, period_col='p1_o')
# Out:
# Fitting Gaia DR3 4658035626229427456
# INFO: Query finished. [astroquery.utils.tap.core]
# saved lightcurve plot to GaiaDR34658035626229427456_gloess_lc.pdf
# GaiaDR34658035626229427456_gloess_fit.csv
# Saved gloess fit to GaiaDR34658035626229427456_gloess_fit.csv

# %%
vc.columns
# Out:
# Index(['solution_id', 'source_id', 'pf', 'pf_error', 'p1_o', 'p1_o_error',
#        'epoch_g', 'epoch_g_error', 'epoch_bp', 'epoch_bp_error', 'epoch_rp',
#        'epoch_rp_error', 'epoch_rv', 'epoch_rv_error', 'int_average_g',
#        'int_average_g_error', 'int_average_bp', 'int_average_bp_error',
#        'int_average_rp', 'int_average_rp_error', 'average_rv',
#        'average_rv_error', 'peak_to_peak_g', 'peak_to_peak_g_error',
#        'peak_to_peak_bp', 'peak_to_peak_bp_error', 'peak_to_peak_rp',
#        'peak_to_peak_rp_error', 'peak_to_peak_rv', 'peak_to_peak_rv_error',
#        'metallicity', 'metallicity_error', 'r21_g', 'r21_g_error', 'r31_g',
#        'r31_g_error', 'phi21_g', 'phi21_g_error', 'phi31_g', 'phi31_g_error',
#        'num_clean_epochs_g', 'num_clean_epochs_bp', 'num_clean_epochs_rp',
#        'num_clean_epochs_rv', 'zp_mag_g', 'zp_mag_bp', 'zp_mag_rp',
#        'num_harmonics_for_p1_g', 'num_harmonics_for_p1_bp',
# ...
